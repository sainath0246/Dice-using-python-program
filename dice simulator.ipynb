# %%
import random
play="yes"
while(play=="yes"):
    d=random.randint(1,6)
    if(d==1):
        print("*",end="\t")
        print("0",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("0",end="\t")
        print("0",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("0",end="\t")
        print("0",end="\t")
    if(d==2):
        print("0",end="\t")
        print("0",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("0",end="\t")
        print("0",end="\t")
    if(d==3):
        print("*",end="\t")
        print("0",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("0",end="\t")
        print("0",end="\t")
    if(d==4):
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("0",end="\t")
        print("0",end="\t")
    if(d==5):
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("*",end="\t")
        print("0",end="\t")
    if(d==6):
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("*",end="\t")
        print("*",end="\t")
        print("",end="\n")
        print("",end="\n")
        print("*",end="\t")
        print("*",end="\t")
    print("",end="\n")
    print("Enter if you want to continue:")
    play=input()
    if(play=='yes'):
        print("",end="\n")
        print("Let's play")
        continue
    else:
        print("I Quit")
# Out:
# *	0
#
# 0	0
#
# 0	0
# Enter if you want to continue:
# yes
#
# Let's play
# *	*
#
# *	*
#
# *	*
# Enter if you want to continue:
# yes
#
# Let's play
# *	*
#
# *	*
#
# *	0
# Enter if you want to continue:
# no
# I Quit
